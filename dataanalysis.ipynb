# %%
import yfinance as yf
import pandas as pd
import ta 

#switch to yahoo finance data 

ticker_symbol = "GLD"  # Gold price in USD

ticker = yf.Ticker(ticker_symbol)

historical_data = ticker.history(period="2y")  # Fetch 1 year of historical data
# Out:
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: XAUUSD=X"}}}
# $XAUUSD=X: possibly delisted; no price data found  (period=2y) (Yahoo error = "No data found, symbol may be delisted")
