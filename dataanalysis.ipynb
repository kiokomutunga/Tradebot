# %%
import yfinance as yf
import pandas as pd
import ta 

#switch to yahoo finance data 

ticker_symbol = "GLD"  # Gold price in USD

ticker = yf.Ticker(ticker_symbol)

historical_data = ticker.history(period="2y")

print(historical_data.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-11-03 00:00:00-04:00  184.479996  185.470001  184.350006  184.789993
# 2023-11-06 00:00:00-05:00  184.139999  184.229996  183.339996  183.350006
# 2023-11-07 00:00:00-05:00  182.250000  182.649994  181.750000  182.589996
# 2023-11-08 00:00:00-05:00  182.009995  182.070007  180.570007  180.770004
# 2023-11-09 00:00:00-05:00  180.979996  182.279999  180.889999  181.490005
#
#                             Volume  Dividends  Stock Splits  Capital Gains
# Date
# 2023-11-03 00:00:00-04:00  8530400        0.0           0.0            0.0
# 2023-11-06 00:00:00-05:00  8274700        0.0           0.0            0.0
# 2023-11-07 00:00:00-05:00  6795800        0.0           0.0            0.0
# 2023-11-08 00:00:00-05:00  6738300        0.0           0.0            0.0
# 2023-11-09 00:00:00-05:00  6486300        0.0           0.0            0.0

# %%
data = yf.download("GC=F", start="2018-01-01", end="2025-10-01", interval="1h")
# Out:
# C:\Users\kioko\AppData\Local\Temp\ipykernel_12524\3849773007.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("GC=F", start="2018-01-01", end="2025-10-01", interval="1h")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GC=F']: YFPricesMissingError('possibly delisted; no price data found  (1h 2018-01-01 -> 2025-10-01) (Yahoo error = "1h data not available for startTime=1514782800 and endTime=1759291200. The requested range must be within the last 730 days.")')

# %%
import yfinance as yf

data = yf.download("GC=F", start="2023-01-01", end="2025-10-01", interval="1h")
print(data.head(), data.tail())
# Out:
# C:\Users\kioko\AppData\Local\Temp\ipykernel_12524\1134343090.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("GC=F", start="2023-01-01", end="2025-10-01", interval="1h")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GC=F']: YFPricesMissingError('possibly delisted; no price data found  (1h 2023-01-01 -> 2025-10-01) (Yahoo error = "1h data not available for startTime=1672549200 and endTime=1759291200. The requested range must be within the last 730 days.")')
# Empty DataFrame
# Columns: [(Adj Close, GC=F), (Close, GC=F), (High, GC=F), (Low, GC=F), (Open, GC=F), (Volume, GC=F)]
# Index: [] Empty DataFrame
# Columns: [(Adj Close, GC=F), (Close, GC=F), (High, GC=F), (Low, GC=F), (Open, GC=F), (Volume, GC=F)]
# Index: []

# %%
import yfinance as yf

data = yf.download("GC=F", period="730d", interval="1h")

print(data.head())
print(data.tail())
print("Data shape:", data.shape)
# Out:
# C:\Users\kioko\AppData\Local\Temp\ipykernel_12524\1519382370.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("GC=F", period="730d", interval="1h")
# [*********************100%***********************]  1 of 1 completed
# Price                            Close         High          Low         Open  \
# Ticker                            GC=F         GC=F         GC=F         GC=F
# Datetime
# 2023-06-14 04:00:00+00:00  1961.900024  1962.699951  1961.000000  1962.400024
# 2023-06-14 05:00:00+00:00  1959.300049  1962.300049  1959.099976  1961.900024
# 2023-06-14 06:00:00+00:00  1959.000000  1960.800049  1958.400024  1959.300049
# 2023-06-14 07:00:00+00:00  1962.800049  1964.800049  1958.099976  1959.000000
# 2023-06-14 08:00:00+00:00  1963.099976  1964.300049  1961.599976  1962.800049
#
# Price                     Volume
# Ticker                      GC=F
# Datetime
# 2023-06-14 04:00:00+00:00      0
# ...

# %%
data.to_csv("gold_data.csv")
print("Data saved to gold_data.csv")#
# Out:
# ✅ Data saved to gold_data.csv
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 data.to_csv("gold_data.csv")
#       2 print("✅ Data saved to gold_data.csv")
# ----> 3 data.to_excel("gold_data.xlsx")
#       4 print("✅ Data saved to gold_data.xlsx")
#
# File c:\Users\kioko\Desktop\xauusd\tradebot\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
data.to_excel("gold_data.xlsx")
print("Data saved to gold_data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data.to_excel("gold_data.xlsx")
#       2 print("Data saved to gold_data.xlsx")
#
# File c:\Users\kioko\Desktop\xauusd\tradebot\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
